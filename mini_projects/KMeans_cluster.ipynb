# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
url = "https://raw.githubusercontent.com/DataScience75/Batch-88/main/iris.json"

# %%
data = pd.read_json(url)
print(data.head(2))
# Out:
#    sepalLength  sepalWidth  petalLength  petalWidth species
# 0          5.1         3.5          1.4         0.2  setosa
# 1          4.9         3.0          1.4         0.2  setosa

# %%
X = data.iloc[:,0:4]
X
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth
# 0            5.1         3.5          1.4         0.2
# 1            4.9         3.0          1.4         0.2
# 2            4.7         3.2          1.3         0.2
# 3            4.6         3.1          1.5         0.2
# 4            5.0         3.6          1.4         0.2
# ..           ...         ...          ...         ...
# 145          6.7         3.0          5.2         2.3
# 146          6.3         2.5          5.0         1.9
# 147          6.5         3.0          5.2         2.0
# 148          6.2         3.4          5.4         2.3
# 149          5.9         3.0          5.1         1.8
#
# [150 rows x 4 columns]

# %%
sc = StandardScaler()
X_scaled = sc.fit_transform(X)
X_scaled
# Out:
# array([[-9.00681170e-01,  1.01900435e+00, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00, -1.31979479e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.38535265e+00,  3.28414053e-01, -1.39706395e+00,
#         -1.31544430e+00],
#        [-1.50652052e+00,  9.82172869e-02, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.02184904e+00,  1.24920112e+00, -1.34022653e+00,
#         -1.31544430e+00],
#        [-5.37177559e-01,  1.93979142e+00, -1.16971425e+00,
#         -1.05217993e+00],
#        [-1.50652052e+00,  7.88807586e-01, -1.34022653e+00,
#         -1.18381211e+00],
#        [-1.02184904e+00,  7.88807586e-01, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.74885626e+00, -3.62176246e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00,  9.82172869e-02, -1.28338910e+00,
#         -1.44707648e+00],
#        [-5.37177559e-01,  1.47939788e+00, -1.28338910e+00,
#         -1.31544430e+00],
# ...

# %%
km = KMeans(n_clusters=5)
km.fit(X_scaled)
pred = km.predict(X_scaled)
pred
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([2, 0, 0, 0, 2, 2, 0, 2, 0, 0, 2, 0, 0, 0, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 0, 0, 0, 2, 2, 2, 0, 0, 2, 2, 2, 0, 0, 2, 2, 0, 2, 2, 0, 0, 2,
#        2, 0, 2, 0, 2, 0, 3, 1, 3, 4, 1, 1, 1, 4, 1, 4, 4, 1, 4, 1, 4, 1,
#        1, 4, 4, 4, 1, 1, 1, 1, 1, 1, 1, 1, 1, 4, 4, 4, 4, 1, 1, 1, 1, 4,
#        1, 4, 4, 1, 4, 4, 4, 1, 1, 1, 4, 4, 3, 1, 3, 1, 3, 3, 4, 3, 1, 3,
#        3, 1, 3, 1, 1, 3, 1, 3, 3, 4, 3, 1, 3, 1, 3, 3, 1, 1, 1, 3, 3, 3,
#        1, 1, 1, 3, 3, 1, 1, 3, 3, 3, 1, 3, 3, 3, 1, 1, 3, 1], dtype=int32)

# %%
km.cluster_centers_
# Out:
# array([[-1.35230687,  0.11914427, -1.31439133, -1.29749445],
#        [ 0.38167879, -0.39095084,  0.60882357,  0.56579901],
#        [-0.74922133,  1.43007001, -1.29759846, -1.22142131],
#        [ 1.39733017,  0.23316022,  1.16062026,  1.21734049],
#        [-0.35279167, -1.33300609,  0.10294988,  0.01232382]])

# %%
sentence = "Ours Cat Name is Luna"
print(sentence.lower())
# Out:
# ours cat name is luna

# %%
sent_list = ['Could You pass me The TV remotE', 'Could You Find The Motel']
print(sent_list)
# Out:
# ['Could You pass me The TV remotE', 'Could You Find The Motel']

# %%
lower_sent_list = [x.lower() for x in sent_list]
print(lower_sent_list)
# Out:
# ['could you pass me the tv remote', 'could you find the motel']

# %%
import re   ## regular expression

# %%
###re.search
search_res = re.search("pattern", r"Find if there is any pattern in the list")
print(search_res)
# Out:
# <re.Match object; span=(21, 28), match='pattern'>

# %%
### re.sub
t = r"Rahul was able to pick it up quickly"
new = re.sub("Rahul","Raj",t)
print(new)
# Out:
# Raj was able to pick it up quickly

# %%
from sklearn.svm import SVC

# %%
x = data[['sepalLength', 'sepalWidth', 'petalLength', 'petalWidth']]
y = data['species']
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)
x_train.shape
# Out:
# (105, 4)

# %%
model = SVC(kernel='rbf' )
model.fit(x_train,y_train)
pred = model.predict(x_test)
pred
# Out:
# array(['setosa', 'setosa', 'setosa', 'setosa', 'versicolor', 'setosa',
#        'setosa', 'virginica', 'virginica', 'versicolor', 'setosa',
#        'virginica', 'virginica', 'versicolor', 'versicolor', 'versicolor',
#        'setosa', 'setosa', 'virginica', 'virginica', 'setosa',
#        'versicolor', 'versicolor', 'virginica', 'versicolor', 'setosa',
#        'versicolor', 'versicolor', 'setosa', 'virginica', 'versicolor',
#        'versicolor', 'setosa', 'setosa', 'virginica', 'versicolor',
#        'versicolor', 'setosa', 'versicolor', 'virginica', 'versicolor',
#        'virginica', 'versicolor', 'virginica', 'virginica'], dtype=object)

# %%
data = pd.read_json(url)
print(data.head(2))
# Out:
#    sepalLength  sepalWidth  petalLength  petalWidth species
# 0          5.1         3.5          1.4         0.2  setosa
# 1          4.9         3.0          1.4         0.2  setosa

# %%
customer_reviews=[]
customer_reviews.append("Great product!Rahul Have a try")
customer_reviews.append("Customer service was excellent")
customer_reviews.append("Not satisfy with the quality needed")

# %%
print(customer_reviews)
# Out:
# ['Great product!Rahul Have a try', 'Customer service was excellent', 'Not satisfy with the quality needed']

# %%
print("customer reviews")
for review in customer_reviews:
  print("- " + review)
# Out:
# customer reviews
# - Great product!Rahul Have a try
# - Customer service was excellent
# - Not satisfy with the quality needed

# %%
rahul_review=[]
patern_to_find = r'Rahul?'  #### ? denotes after rahul if there is any patern bring those sentences also

# %%
for s in customer_reviews:
  if re.search(patern_to_find,s):
    rahul_review.append(s)

# %%
print(rahul_review)
# Out:
# ['Great product!Rahul Have a try']

# %%
g_review=[]
pattern_to_find = r'^G'  #### ^ start of the string with letter G

# %%
for g in customer_reviews:
  if re.search(pattern_to_find,g):
    g_review.append(g)

# %%
print(g_review)
# Out:
# ['Great product!Rahul Have a try']
